# %% [markdown]
# # Import

# %%
import cv2
import matplotlib.pyplot as plt
import os, os.path
import numpy as np

# %% [markdown]
# # 윤곽선

# %%
def pause() :
    keycode = cv2.waitKey(0)
    if keycode == 27:         
        cv2.destroyAllWindows()

# %%
def getxy() :
    x_min, x_max = 0,0
    value = list()
    for i in range(len(contours_xy)):
        for j in range(len(contours_xy[i])):
            value.append(contours_xy[i][j][0][0]) #네번째 괄호가 0일때 x의 값
            x_min = min(value)
            x_max = max(value)
    y_min, y_max = 0,0
    value = list()
    for i in range(len(contours_xy)):
        for j in range(len(contours_xy[i])):
            value.append(contours_xy[i][j][0][1]) #네번째 괄호가 0일때 x의 값
            y_min = min(value)
            y_max = max(value)
    x = x_min
    y = y_min
    w = x_max-x_min
    h = y_max-y_min
    img_trim = img[y:y+h, x:x+w]
    return img_trim, h, w

# %%
img_dir = 'D:/hackathon/이미지사운드매칭_해커톤_데이터셋/이미지/원천데이터/교통/선박 운항/'
save_dir = 'D:/hackathon/data_preprocessing/ship/'
ind = 0
for file in os.listdir(img_dir) :
    ind += 1
#     if ind != 1 :
#         continue
    full_path = np.fromfile(img_dir+file, np.uint8)
    img = cv2.imdecode(full_path, cv2.IMREAD_COLOR)
    img_gray = cv2.imdecode(full_path, cv2.IMREAD_GRAYSCALE)
    filt = cv2.bilateralFilter(img_gray, -1, 20, 20)
    blur = cv2.GaussianBlur(filt, (3,3), 2)
    ret1, thresh1 = cv2.threshold(255-blur, 210, 255, cv2.THRESH_BINARY)
    # ret2, thresh2 = cv2.threshold(blur, 210, 255, cv2.THRESH_BINARY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))
    closed1 = cv2.morphologyEx(thresh1, cv2.MORPH_CLOSE, kernel)
    # closed2 = cv2.morphologyEx(thresh2, cv2.MORPH_CLOSE, kernel)
    contours1, _ = cv2.findContours(closed1.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    # contours2, _ = cv2.findContours(closed2.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     if np.array(contours1).size == 0 and np.array(contours2).size == 0 :
#         continue
#     if np.array(contours1).size > np.array(contours2).size :
#         contours_xy = np.array(contours2)
#         contours = contours2
#     else :
#         contours_xy = np.array(contours1)
#         contours = contours1
    # contours_image = cv2.drawContours(img, contours, -1, (0,255,0), 3)
    contours_xy = np.array(contours1)
    final_img, h, w = getxy()
    # plt.imshow(final_img)
#     cv2.namedWindow("test",0)
#     cv2.resizeWindow("test", 640, 480)
#     cv2.imshow("test",contours_image)
#     pause()
    extension = os.path.splitext(file)[1]
    result, encoded_img = cv2.imencode(extension, final_img)
    if result:
        with open(save_dir+file, mode='w+b') as f:
            encoded_img.tofile(f)
    print(f"{ind}. {file} save")
    break
# Out:
# <ipython-input-26-a33d7b66ea58>:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   contours_xy = np.array(contours1)
# 1. 선박 운항_어선_Im10245857.jpg save
# 2. 선박 운항_어선_Im10245858.jpg save
# 3. 선박 운항_어선_Im10245860.jpg save
# 4. 선박 운항_어선_Im10245861.jpg save
# 5. 선박 운항_어선_Im10245862.jpg save
# 6. 선박 운항_어선_Im10245863.jpg save
# 7. 선박 운항_어선_Im10245864.jpg save
# 8. 선박 운항_어선_Im10245865.jpg save
# 9. 선박 운항_어선_Im10245866.jpg save
# 10. 선박 운항_어선_Im10245867.jpg save
# 11. 선박 운항_어선_Im10245868.jpg save
# 12. 선박 운항_어선_Im10245869.jpg save
# 13. 선박 운항_어선_Im10245870.jpg save
# 14. 선박 운항_어선_Im10245871.jpg save
# 15. 선박 운항_어선_Im10245872.jpg save
# 16. 선박 운항_어선_Im10245873.jpg save
# 17. 선박 운항_어선_Im10245874.jpg save
# 18. 선박 운항_어선_Im10245875.jpg save
# 19. 선박 운항_어선_Im10245876.jpg save
# ...

# %%
img_dir = 'D:/hackathon/이미지사운드매칭_해커톤_데이터셋/이미지/원천데이터/교통/경고음/'
save_dir = 'D:/hackathon/data_preprocessing/구급차/'
ind = 0
for file in os.listdir(img_dir) :
    ind += 1
    if ind <= 14 :
        continue
    full_path = np.fromfile(img_dir+file, np.uint8)
    img = cv2.imdecode(full_path, cv2.IMREAD_COLOR)
    img_gray = cv2.imdecode(full_path, cv2.IMREAD_GRAYSCALE)
    filt = cv2.bilateralFilter(img_gray, -1, 20, 20)
    blur = cv2.GaussianBlur(filt, (1,1), 5)
    ret1, thresh1 = cv2.threshold(blur, 210, 255, cv2.THRESH_BINARY)
    # ret2, thresh2 = cv2.threshold(blur, 210, 255, cv2.THRESH_BINARY)
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7,7))
    closed1 = cv2.morphologyEx(thresh1, cv2.MORPH_CLOSE, kernel)
    # closed2 = cv2.morphologyEx(thresh2, cv2.MORPH_CLOSE, kernel)
    contours1, _ = cv2.findContours(closed1.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    # contours2, _ = cv2.findContours(closed2.copy(),cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#     if np.array(contours1).size == 0 and np.array(contours2).size == 0 :
#         continue
#     if np.array(contours1).size > np.array(contours2).size :
#         contours_xy = np.array(contours2)
#         contours = contours2
#     else :
#         contours_xy = np.array(contours1)
#         contours = contours1
    # contours_image = cv2.drawContours(img, contours, -1, (0,255,0), 3)
    contours_xy = np.array(contours1)
    final_img, h, w = getxy()
    # plt.imshow(final_img)
#     cv2.namedWindow("test",0)
#     cv2.resizeWindow("test", 640, 480)
#     cv2.imshow("test",final_img)
#     pause()
    extension = os.path.splitext(file)[1]
    result, encoded_img = cv2.imencode(extension, final_img)
    if result:
        with open(save_dir+file, mode='w+b') as f:
            encoded_img.tofile(f)
    print(f"{ind}. {file} save")
# Out:
# <ipython-input-8-dc602531c46d>:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   contours_xy = np.array(contours1)
# 15. 경고음_구급차_Im10100033.jpg save
# 16. 경고음_구급차_Im10106881.jpg save
# 17. 경고음_구급차_Im10236761.jpg save
# 18. 경고음_구급차_Im10236763.jpg save
# 19. 경고음_구급차_Im10236764.jpg save
# 20. 경고음_구급차_Im10236765.jpg save
# 21. 경고음_구급차_Im10236768.jpg save
# 22. 경고음_구급차_Im10236770.jpg save
# 23. 경고음_구급차_Im10276902.jpg save
