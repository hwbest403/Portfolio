# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) * 0.01

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# assume some unit gaussian 500-D input data
D = np.random.randn(1000, 500)
hidden_layer_sizes = [500]*10
#print(hidden_layer_sizes)
#print(len(hidden_layer_sizes))
nonlinearities = ['tanh']*len(hidden_layer_sizes)
#nonlinearities = ['relu']*len(hidden_layer_sizes)
#print(nonlinearities)

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    print([fan_in, fan_out])
    W = np.random.randn(fan_in, fan_out) * 0.01 # layer initialization, 500x500
    #print([X.shape, W.shape])
    H = np.dot(X,W) # matrix multiply, X: 1000x500, W 500x500
    #print(f'H.shape : {H.shape}')
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer
# Out:
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]
# [500, 500]

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000192 and std 1.000779
# hidden layer 1 had mean -0.000067 and std 0.213812
# hidden layer 2 had mean 0.000054 and std 0.047863
# hidden layer 3 had mean 0.000029 and std 0.010688
# hidden layer 4 had mean -0.000002 and std 0.002399
# hidden layer 5 had mean -0.000000 and std 0.000536
# hidden layer 6 had mean -0.000000 and std 0.000120
# hidden layer 7 had mean -0.000000 and std 0.000027
# hidden layer 8 had mean 0.000000 and std 0.000006
# hidden layer 9 had mean 0.000000 and std 0.000001
# hidden layer 10 had mean 0.000000 and std 0.000000

# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) * 1.0

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) * 1.0 # layer initialization
    
    H = np.dot(X,W) # matrix multiply
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000192 and std 1.000779
# hidden layer 1 had mean 0.000200 and std 0.982027
# hidden layer 2 had mean -0.001696 and std 0.981610
# hidden layer 3 had mean -0.000641 and std 0.981748
# hidden layer 4 had mean 0.000975 and std 0.981710
# hidden layer 5 had mean -0.002785 and std 0.981698
# hidden layer 6 had mean -0.000109 and std 0.981717
# hidden layer 7 had mean 0.000336 and std 0.981778
# hidden layer 8 had mean -0.001111 and std 0.981719
# hidden layer 9 had mean 0.000011 and std 0.981775
# hidden layer 10 had mean 0.001672 and std 0.981600

# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in)

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in) # layer initialization
    
    H = np.dot(X,W) # matrix multiply
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000192 and std 1.000779
# hidden layer 1 had mean 0.000003 and std 0.627606
# hidden layer 2 had mean 0.000076 and std 0.486057
# hidden layer 3 had mean -0.000189 and std 0.408089
# hidden layer 4 had mean -0.000706 and std 0.357249
# hidden layer 5 had mean -0.000211 and std 0.320975
# hidden layer 6 had mean 0.000358 and std 0.292722
# hidden layer 7 had mean -0.000233 and std 0.271351
# hidden layer 8 had mean -0.000241 and std 0.255816
# hidden layer 9 had mean -0.000333 and std 0.242193
# hidden layer 10 had mean -0.000059 and std 0.229417

# %% [markdown]
# # W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in/2)

# %%
act = {'relu':lambda x: np.maximum(0,x), 'tanh':lambda x:np.tanh(x)}
Hs = {}
for i in range(len(hidden_layer_sizes)):
    X = D if i == 0 else Hs[i-1] # input at this layer
    fan_in = X.shape[1]
    fan_out = hidden_layer_sizes[i]
    W = np.random.randn(fan_in, fan_out) / np.sqrt(fan_in/2) # layer initialization
    
    H = np.dot(X,W) # matrix multiply
    H = act[nonlinearities[i]](H)
    Hs[i] = H # cache result on this layer

# %%
# look at distributions at each layer
print ('input layer had mean %f and std %f' % (np.mean(D), np.std(D)))
layer_means = [np.mean(H) for i,H in Hs.items()]
layer_stds = [np.std(H) for i,H in Hs.items()]
for i,H in Hs.items():
    print ('hidden layer %d had mean %f and std %f' % (i+1, layer_means[i], layer_stds[i]))
    
# plot the means and standard deviations
plt.figure()
plt.subplot(121)
plt.plot(Hs.keys(), layer_means, 'ob-')
plt.title('layer mean')
plt.subplot(122)
plt.plot(Hs.keys(), layer_stds, 'or-')
plt.title('layer std')

# plot the raw distributions
plt.figure()
for i,H in Hs.items():
    plt.subplot(1,len(Hs), i+1)
    plt.hist(H.ravel(), 30, range=(-1,1))
# Out:
# input layer had mean -0.000192 and std 1.000779
# hidden layer 1 had mean 0.000405 and std 0.721036
# hidden layer 2 had mean -0.000991 and std 0.633238
# hidden layer 3 had mean 0.000226 and std 0.596078
# hidden layer 4 had mean 0.001352 and std 0.576972
# hidden layer 5 had mean -0.000413 and std 0.566549
# hidden layer 6 had mean -0.000781 and std 0.561833
# hidden layer 7 had mean -0.000525 and std 0.559615
# hidden layer 8 had mean -0.000414 and std 0.557943
# hidden layer 9 had mean 0.000637 and std 0.556392
# hidden layer 10 had mean -0.000290 and std 0.556182
